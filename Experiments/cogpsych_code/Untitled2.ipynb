# %%
import sqlite3
import os
import pickle
import pandas as pd
import sys

execfile('Imports.py')

from Modules.Classes import Simulation

#Allow terminal input argument
# narg = len(sys.argv)
# if __name__ == "__main__" and narg>1:
#     expName = sys.argv[1] #idx 1 arg from terminal is the experiment name
#     compilation = False #by default not a compilation of exps
#     if narg>2:
#         compilation = sys.argv[2] #idx 2 must be Boolean and indicates if experiment db is a compilation of multiple exps
# else:
expName = 'xcrABC' #default experiment name
compilation = False

#Extract only specific conditions. Specify as a list.
extractcond = None

#This list of exps are known to be compilations:
if expName in ['pooled','5con','5con_s']:
    compilation = True

    
#Toggle construction of trialset pickle without first trial?
# This is in addition to the usual.
# Regular full set of trials is always constructed.
no1st = False

if compilation:
    pluralStr = 's'
else:
    pluralStr = ''

if len(expName)==0:
    expNameExt = ''
else:
    expNameExt = '-'
    
con = sqlite3.connect('experiment{}{}{}.db'.format(pluralStr,expNameExt,expName))
participants = pd.read_sql_query("SELECT participant, condition, gentype from participants", con)
generation = pd.read_sql_query("SELECT * from generation", con)
alphas = pd.read_sql_query("SELECT * from alphas", con)
stimuli = pd.read_sql_query("SELECT * from stimuli", con).values
con.close()

print('Extracting trialsets from experiment: {}'.format(expName))

# create categories mapping
mapping = pd.DataFrame(columns = ['condition', 'categories'])
for i in alphas.columns:
	As = alphas[i].values.flatten()
	mapping = mapping.append(
		dict(condition = i, categories =[As]), 
		ignore_index = True
	)
        
# merge categories into generation
generation = pd.merge(generation, participants, on='participant')
generation = pd.merge(generation, mapping, on='condition')
# Out:
# Extracting trialsets from experiment: xcrABC

# %%
genbatch = generation[generation.gentype==1]

# %%
genbatch
# Out:
#      category  participant     rt  stimulus  trial condition  gentype  \
# 0        Beta            3   4391       179      1   Cluster        1
# 1        Beta            3  11435        29      0   Cluster        1
# 2        Beta            3   1799        66      3   Cluster        1
# 3        Beta            3   3421       169      2   Cluster        1
# 4        Beta            3   3931       120      5   Cluster        1
# 5        Beta            3   4291       308      4   Cluster        1
# 6        Beta            3   5667       218      7   Cluster        1
# 7        Beta            3   4741       217      6   Cluster        1
# 40       Beta          132  11277      2349      1   Cluster        1
# 41       Beta          132  19084      2499      0   Cluster        1
# 42       Beta          132  40118      2398      3   Cluster        1
# 43       Beta          132   7831      2449      2   Cluster        1
# 44       Beta          132  31404      2447      5   Cluster        1
# 45       Beta          132   4574      2448      4   Cluster        1
# 46       Beta          132  33442      1748      7   Cluster        1
# 47       Beta          132  39428      2441      6   Cluster        1
# 64       Beta          145   8521      2076      1   Cluster        1
# 65       Beta          145   9664      2284      0   Cluster        1
# 66       Beta          145   5473      2338      3   Cluster        1
# 67       Beta          145   5607      1886      2   Cluster        1
# 68       Beta          145   6952      2335      5   Cluster        1
# 69       Beta          145   2968      2381      4   Cluster        1
# 70       Beta          145   3324      2433      7   Cluster        1
# 71       Beta          145   3799      2438      6   Cluster        1
# 72       Beta          152   7743      2450      1   Cluster        1
# 73       Beta          152   4647      1469      0   Cluster        1
# 74       Beta          152   7286       835      3   Cluster        1
# 75       Beta          152   5669      1874      2   Cluster        1
# 76       Beta          152   6524       983      5   Cluster        1
# 77       Beta          152   9556       788      4   Cluster        1
# ...       ...          ...    ...       ...    ...       ...      ...
# 1810     Beta          381   7221      2482      3       XOR        1
# 1811     Beta          381   8055      2100      2       XOR        1
# 1812     Beta          381   5552         0      5       XOR        1
# 1813     Beta          381   6757        23      4       XOR        1
# 1814     Beta          381   7479      2477      7       XOR        1
# 1815     Beta          381   5065        49      6       XOR        1
# 1816     Beta          382   9929        45      1       XOR        1
# 1817     Beta          382  15545        49      0       XOR        1
# 1818     Beta          382   5585        33      3       XOR        1
# 1819     Beta          382   7850        40      2       XOR        1
# 1820     Beta          382   4237        14      5       XOR        1
# 1821     Beta          382   4145        23      4       XOR        1
# 1822     Beta          382   4527         1      7       XOR        1
# 1823     Beta          382   4170         8      6       XOR        1
# 1832     Beta          393   4778      2161      1       XOR        1
# 1833     Beta          393   9668       437      0       XOR        1
# 1834     Beta          393   5828      2473      3       XOR        1
# 1835     Beta          393   3402      2450      2       XOR        1
# 1836     Beta          393   4719       385      5       XOR        1
# 1837     Beta          393   4112        42      4       XOR        1
# 1838     Beta          393   2694        37      7       XOR        1
# 1839     Beta          393   5375       522      6       XOR        1
# 1880     Beta          421  13670      2450      1       XOR        1
# 1881     Beta          421  12889        49      0       XOR        1
# 1882     Beta          421   9396      2200      3       XOR        1
# 1883     Beta          421  11859       580      2       XOR        1
# 1884     Beta          421  10268       699      5       XOR        1
# 1885     Beta          421   5293         0      4       XOR        1
# 1886     Beta          421   7674      1718      7       XOR        1
# 1887     Beta          421   6148      1307      6       XOR        1
#
#                     categories
# 0     [[583, 392, 1083, 1093]]
# 1     [[583, 392, 1083, 1093]]
# 2     [[583, 392, 1083, 1093]]
# 3     [[583, 392, 1083, 1093]]
# 4     [[583, 392, 1083, 1093]]
# 5     [[583, 392, 1083, 1093]]
# 6     [[583, 392, 1083, 1093]]
# 7     [[583, 392, 1083, 1093]]
# 40    [[583, 392, 1083, 1093]]
# 41    [[583, 392, 1083, 1093]]
# 42    [[583, 392, 1083, 1093]]
# 43    [[583, 392, 1083, 1093]]
# 44    [[583, 392, 1083, 1093]]
# 45    [[583, 392, 1083, 1093]]
# 46    [[583, 392, 1083, 1093]]
# 47    [[583, 392, 1083, 1093]]
# 64    [[583, 392, 1083, 1093]]
# 65    [[583, 392, 1083, 1093]]
# 66    [[583, 392, 1083, 1093]]
# 67    [[583, 392, 1083, 1093]]
# 68    [[583, 392, 1083, 1093]]
# 69    [[583, 392, 1083, 1093]]
# 70    [[583, 392, 1083, 1093]]
# 71    [[583, 392, 1083, 1093]]
# 72    [[583, 392, 1083, 1093]]
# 73    [[583, 392, 1083, 1093]]
# 74    [[583, 392, 1083, 1093]]
# 75    [[583, 392, 1083, 1093]]
# 76    [[583, 392, 1083, 1093]]
# 77    [[583, 392, 1083, 1093]]
# ...                        ...
# 1810  [[403, 818, 1479, 1890]]
# 1811  [[403, 818, 1479, 1890]]
# 1812  [[403, 818, 1479, 1890]]
# 1813  [[403, 818, 1479, 1890]]
# 1814  [[403, 818, 1479, 1890]]
# 1815  [[403, 818, 1479, 1890]]
# 1816  [[403, 818, 1479, 1890]]
# 1817  [[403, 818, 1479, 1890]]
# 1818  [[403, 818, 1479, 1890]]
# 1819  [[403, 818, 1479, 1890]]
# 1820  [[403, 818, 1479, 1890]]
# 1821  [[403, 818, 1479, 1890]]
# 1822  [[403, 818, 1479, 1890]]
# 1823  [[403, 818, 1479, 1890]]
# 1832  [[403, 818, 1479, 1890]]
# 1833  [[403, 818, 1479, 1890]]
# 1834  [[403, 818, 1479, 1890]]
# 1835  [[403, 818, 1479, 1890]]
# 1836  [[403, 818, 1479, 1890]]
# 1837  [[403, 818, 1479, 1890]]
# 1838  [[403, 818, 1479, 1890]]
# 1839  [[403, 818, 1479, 1890]]
# 1880  [[403, 818, 1479, 1890]]
# 1881  [[403, 818, 1479, 1890]]
# 1882  [[403, 818, 1479, 1890]]
# 1883  [[403, 818, 1479, 1890]]
# 1884  [[403, 818, 1479, 1890]]
# 1885  [[403, 818, 1479, 1890]]
# 1886  [[403, 818, 1479, 1890]]
# 1887  [[403, 818, 1479, 1890]]
#
# [656 rows x 8 columns]

# %%
participants[participants.gentype==2].participant
# Out:
# 3       37
# 7      126
# 11     130
# 20     144
# 24     149
# 25     150
# 28     153
# 35     163
# 39     167
# 41     170
# 45     174
# 49     178
# 51     181
# 53     183
# 55     185
# 56     188
# 60     194
# 63     198
# 65     200
# 68     206
# 73     211
# 96     245
# 98     247
# 106    258
# 109    261
# 114    266
# 115    267
# 116    268
# 118    273
# 128    285
#       ...
# 165    337
# 166    338
# 169    344
# 171    347
# 172    348
# 173    350
# 174    351
# 175    352
# 181    361
# 182    363
# 186    371
# 188    373
# 189    374
# 192    378
# 197    385
# 199    388
# 200    390
# 201    391
# 208    398
# 210    402
# 212    404
# 213    405
# 215    408
# 217    410
# 221    420
# 223    422
# 225    425
# 226    426
# 228    428
# 234    434
# Name: participant, Length: 76, dtype: int64

# %%
with open('pickles/xcrC.p','rb') as f:
    trials = pickle.load(f)
print(trials.participants)
print(len(trials.participants))
trials.Set
# Out:
# [ 37. 126. 130. 144. 149. 150. 153. 163. 167. 170. 174. 178. 181. 183.
#  185. 188. 194. 198. 200. 206. 211. 245. 247. 258. 261. 266. 267. 268.
#  273. 285. 286. 288. 290. 293. 296. 301. 306. 310. 312. 314. 316. 318.
#  319. 321. 330. 334. 337. 338. 344. 347. 348. 350. 351. 352. 361. 363.
#  371. 373. 374. 378. 385. 388. 390. 391. 398. 402. 404. 405. 408. 410.
#  420. 422. 425. 426. 428. 434.]
# 76
# [{'categories': [array([ 403,  818, 1479, 1890]), array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([ 37, 130, 144, 149, 150, 181, 183, 194, 247, 258, 285, 286, 288,
#           290, 310, 312, 318, 330, 334, 337, 363, 373, 402, 420, 422, 426])],
#   'response': [array([], dtype=int64),
#    array([1899,  299,  621, 2499, 1202,   49,   18, 1119, 2353, 2336, 1849,
#           2499,   49, 2249,   49, 2104,  982, 2349, 1386,   49, 2499,   49,
#              0, 2499, 2499, 2450])],
#   'wrap_ax': [array([], dtype=int64),
#    array([None, None, None, None, None, None, None, None, None, None, None,
#           None, None, None, None, None, None, None, None, None, None, None,
#           None, None, None, None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1899])],
#   'participant': [array([], dtype=int64), array([37])],
#   'response': [array([], dtype=int64), array([2498])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1899, 2498])],
#   'participant': [array([], dtype=int64), array([37])],
#   'response': [array([], dtype=int64), array([2344])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1899, 2344, 2498])],
#   'participant': [array([], dtype=int64), array([37])],
#   'response': [array([], dtype=int64), array([1994])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1899, 1994, 2344, 2498]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64), array([], dtype=int64), array([37])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1890])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1899, 1994, 2344, 2498]),
#    array([1890])],
#   'participant': [array([], dtype=int64), array([], dtype=int64), array([37])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2092])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1899, 1994, 2344, 2498]),
#    array([1890, 2092])],
#   'participant': [array([], dtype=int64), array([], dtype=int64), array([37])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2190])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1899, 1994, 2344, 2498]),
#    array([1890, 2092, 2190])],
#   'participant': [array([], dtype=int64), array([], dtype=int64), array([37])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2191])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([126, 167, 170, 185, 245, 261, 267, 268, 293, 301, 306, 319, 338,
#           344, 347, 348, 374, 378, 385, 398, 405, 408, 410, 428, 434])],
#   'response': [array([], dtype=int64),
#    array([1350, 2449, 2459, 2210,    0,   99, 1808, 2256, 2495, 1474, 2450,
#           1250,  575,  969,   49, 2000, 2469, 2150, 2471,  100, 2450, 2450,
#           1450, 2499, 1654])],
#   'wrap_ax': [array([], dtype=int64),
#    array([None, None, None, None, None, None, None, None, None, None, None,
#           None, None, None, None, None, None, None, None, None, None, None,
#           None, None, None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1350])],
#   'participant': [array([], dtype=int64), array([126])],
#   'response': [array([], dtype=int64), array([1650])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1350, 1650])],
#   'participant': [array([], dtype=int64), array([126])],
#   'response': [array([], dtype=int64), array([1450])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1350, 1450, 1650])],
#   'participant': [array([], dtype=int64), array([126])],
#   'response': [array([], dtype=int64), array([1150])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1150, 1350, 1450, 1650]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([126])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2470])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1150, 1350, 1450, 1650]),
#    array([2470])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([126])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2466])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1150, 1350, 1450, 1650]),
#    array([2466, 2470])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([126])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2469])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1150, 1350, 1450, 1650]),
#    array([2466, 2469, 2470])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([126])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2467])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([299])],
#   'participant': [array([], dtype=int64), array([130])],
#   'response': [array([], dtype=int64), array([1170])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 299, 1170])],
#   'participant': [array([], dtype=int64), array([130])],
#   'response': [array([], dtype=int64), array([2452])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 299, 1170, 2452])],
#   'participant': [array([], dtype=int64), array([130])],
#   'response': [array([], dtype=int64), array([2073])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 299, 1170, 2073, 2452]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([130])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([0])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 299, 1170, 2073, 2452]),
#    array([0])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([130])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1400])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 299, 1170, 2073, 2452]),
#    array([   0, 1400])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([130])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2100])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 299, 1170, 2073, 2452]),
#    array([   0, 1400, 2100])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([130])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([621])],
#   'participant': [array([], dtype=int64), array([144])],
#   'response': [array([], dtype=int64), array([1075])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 621, 1075])],
#   'participant': [array([], dtype=int64), array([144])],
#   'response': [array([], dtype=int64), array([812])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 621,  812, 1075])],
#   'participant': [array([], dtype=int64), array([144])],
#   'response': [array([], dtype=int64), array([2020])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 621,  812, 1075, 2020]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([144])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1718])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 621,  812, 1075, 2020]),
#    array([1718])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([144])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1129])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 621,  812, 1075, 2020]),
#    array([1129, 1718])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([144])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([983])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 621,  812, 1075, 2020]),
#    array([ 983, 1129, 1718])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([144])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1326])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([2499])],
#   'participant': [array([], dtype=int64), array([149, 286, 363, 420, 422])],
#   'response': [array([], dtype=int64), array([  49,   49, 2475, 2095, 2271])],
#   'wrap_ax': [array([], dtype=int64),
#    array([None, None, None, None, None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([  49, 2499])],
#   'participant': [array([], dtype=int64), array([149, 286, 288, 310])],
#   'response': [array([], dtype=int64), array([2450, 2450, 1349, 1249])],
#   'wrap_ax': [array([], dtype=int64),
#    array([None, None, None, None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([  49, 2450, 2499])],
#   'participant': [array([], dtype=int64), array([149, 286])],
#   'response': [array([], dtype=int64), array([2493,    0])],
#   'wrap_ax': [array([], dtype=int64), array([None, None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  49, 2450, 2493, 2499]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([149])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([849])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  49, 2450, 2493, 2499]),
#    array([849])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([149])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1349])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  49, 2450, 2493, 2499]),
#    array([ 849, 1349])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([149])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([399])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  49, 2450, 2493, 2499]),
#    array([ 399,  849, 1349])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([149])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1749])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1202])],
#   'participant': [array([], dtype=int64), array([150])],
#   'response': [array([], dtype=int64), array([1786])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1202, 1786])],
#   'participant': [array([], dtype=int64), array([150])],
#   'response': [array([], dtype=int64), array([270])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 270, 1202, 1786])],
#   'participant': [array([], dtype=int64), array([150])],
#   'response': [array([], dtype=int64), array([2447])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 270, 1202, 1786, 2447]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([150])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([100])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 270, 1202, 1786, 2447]),
#    array([100])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([150])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1225])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 270, 1202, 1786, 2447]),
#    array([ 100, 1225])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([150])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([849])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 270, 1202, 1786, 2447]),
#    array([ 100,  849, 1225])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([150])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1922])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([153, 163, 174, 178, 188, 198, 200, 206, 211, 266, 273, 296, 314,
#           316, 321, 350, 351, 352, 361, 371, 388, 390, 391, 404, 425])],
#   'response': [array([], dtype=int64),
#    array([   0,  603,   49, 2450, 2450, 1886,  254, 2453,  850, 2400, 2450,
#           1944,  860,  392, 2474, 2463, 2409, 1180, 2330, 2491, 1998, 2043,
#           2450, 1018,    0])],
#   'wrap_ax': [array([], dtype=int64),
#    array([None, None, None, None, None, None, None, None, None, None, None,
#           None, None, None, None, None, None, None, None, None, None, None,
#           None, None, None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([0])],
#   'participant': [array([], dtype=int64), array([153, 425])],
#   'response': [array([], dtype=int64), array([16,  2])],
#   'wrap_ax': [array([], dtype=int64), array([None, None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([ 0, 16])],
#   'participant': [array([], dtype=int64), array([153])],
#   'response': [array([], dtype=int64), array([31])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([ 0, 16, 31])],
#   'participant': [array([], dtype=int64), array([153])],
#   'response': [array([], dtype=int64), array([49])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 0, 16, 31, 49]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([153])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([300])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 0, 16, 31, 49]),
#    array([300])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([153])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([267])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 0, 16, 31, 49]),
#    array([267, 300])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([153])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([281])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 0, 16, 31, 49]),
#    array([267, 281, 300])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([153])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([299])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([603])],
#   'participant': [array([], dtype=int64), array([163])],
#   'response': [array([], dtype=int64), array([504])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([504, 603])],
#   'participant': [array([], dtype=int64), array([163])],
#   'response': [array([], dtype=int64), array([1111])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([ 504,  603, 1111])],
#   'participant': [array([], dtype=int64), array([163])],
#   'response': [array([], dtype=int64), array([909])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 504,  603,  909, 1111]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([163])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1008])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 504,  603,  909, 1111]),
#    array([1008])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([163])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1110])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 504,  603,  909, 1111]),
#    array([1008, 1110])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([163])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([704])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 504,  603,  909, 1111]),
#    array([ 704, 1008, 1110])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([163])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([759])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2449])],
#   'participant': [array([], dtype=int64), array([167])],
#   'response': [array([], dtype=int64), array([2144])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2144, 2449])],
#   'participant': [array([], dtype=int64), array([167])],
#   'response': [array([], dtype=int64), array([2099])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2099, 2144, 2449])],
#   'participant': [array([], dtype=int64), array([167])],
#   'response': [array([], dtype=int64), array([2445])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2099, 2144, 2445, 2449]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([167])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([104])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2099, 2144, 2445, 2449]),
#    array([104])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([167])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([350])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2099, 2144, 2445, 2449]),
#    array([104, 350])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([167])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([5])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2099, 2144, 2445, 2449]),
#    array([  5, 104, 350])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([167])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([258])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2459])],
#   'participant': [array([], dtype=int64), array([170])],
#   'response': [array([], dtype=int64), array([2400])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2400, 2459])],
#   'participant': [array([], dtype=int64), array([170])],
#   'response': [array([], dtype=int64), array([2253])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2253, 2400, 2459])],
#   'participant': [array([], dtype=int64), array([170])],
#   'response': [array([], dtype=int64), array([2155])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2155, 2253, 2400, 2459]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([170])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([31])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2155, 2253, 2400, 2459]),
#    array([31])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([170])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([181])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2155, 2253, 2400, 2459]),
#    array([ 31, 181])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([170])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([88])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2155, 2253, 2400, 2459]),
#    array([ 31,  88, 181])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([170])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([198])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([49])],
#   'participant': [array([], dtype=int64), array([174])],
#   'response': [array([], dtype=int64), array([44])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([44, 49])],
#   'participant': [array([], dtype=int64), array([174])],
#   'response': [array([], dtype=int64), array([47])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([44, 47, 49])],
#   'participant': [array([], dtype=int64), array([174])],
#   'response': [array([], dtype=int64), array([43])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([43, 44, 47, 49]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([174])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([43, 44, 47, 49]),
#    array([2450])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([174])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2452])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([43, 44, 47, 49]),
#    array([2450, 2452])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([174])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2457])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([43, 44, 47, 49]),
#    array([2450, 2452, 2457])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([174])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2460])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2450])],
#   'participant': [array([], dtype=int64), array([178, 188, 273, 391])],
#   'response': [array([], dtype=int64), array([2461, 2499, 2459, 2457])],
#   'wrap_ax': [array([], dtype=int64),
#    array([None, None, None, None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2450, 2461])],
#   'participant': [array([], dtype=int64), array([178])],
#   'response': [array([], dtype=int64), array([2476])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2450, 2461, 2476])],
#   'participant': [array([], dtype=int64), array([178])],
#   'response': [array([], dtype=int64), array([2490])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2461, 2476, 2490]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([178])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1249])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2461, 2476, 2490]),
#    array([1249])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([178])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1237])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2461, 2476, 2490]),
#    array([1237, 1249])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([178])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1116])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2461, 2476, 2490]),
#    array([1116, 1237, 1249])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([178])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1100])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([49])],
#   'participant': [array([], dtype=int64), array([181, 288, 310, 337, 373])],
#   'response': [array([], dtype=int64), array([ 142, 2499, 2499,  149,    0])],
#   'wrap_ax': [array([], dtype=int64),
#    array([None, None, None, None, None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 49, 142])],
#   'participant': [array([], dtype=int64), array([181])],
#   'response': [array([], dtype=int64), array([26])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 26,  49, 142])],
#   'participant': [array([], dtype=int64), array([181])],
#   'response': [array([], dtype=int64), array([0])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  0,  26,  49, 142]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([181])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2499])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  0,  26,  49, 142]),
#    array([2499])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([181])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2237])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  0,  26,  49, 142]),
#    array([2237, 2499])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([181])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2122])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  0,  26,  49, 142]),
#    array([2122, 2237, 2499])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([181])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([18])],
#   'participant': [array([], dtype=int64), array([183])],
#   'response': [array([], dtype=int64), array([24])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([18, 24])],
#   'participant': [array([], dtype=int64), array([183])],
#   'response': [array([], dtype=int64), array([379])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([ 18,  24, 379])],
#   'participant': [array([], dtype=int64), array([183])],
#   'response': [array([], dtype=int64), array([396])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 18,  24, 379, 396]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([183])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1250])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 18,  24, 379, 396]),
#    array([1250])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([183])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([659])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 18,  24, 379, 396]),
#    array([ 659, 1250])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([183])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([770])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([ 18,  24, 379, 396]),
#    array([ 659,  770, 1250])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([183])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([276])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2210])],
#   'participant': [array([], dtype=int64), array([185])],
#   'response': [array([], dtype=int64), array([1968])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1968, 2210])],
#   'participant': [array([], dtype=int64), array([185])],
#   'response': [array([], dtype=int64), array([2476])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1968, 2210, 2476])],
#   'participant': [array([], dtype=int64), array([185])],
#   'response': [array([], dtype=int64), array([9])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([   9, 1968, 2210, 2476]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([185])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2499])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([   9, 1968, 2210, 2476]),
#    array([2499])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([185])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2475])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([   9, 1968, 2210, 2476]),
#    array([2475, 2499])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([185])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([   9, 1968, 2210, 2476]),
#    array([2450, 2475, 2499])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([185])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1778])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2450, 2499])],
#   'participant': [array([], dtype=int64), array([188])],
#   'response': [array([], dtype=int64), array([2476])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2450, 2476, 2499])],
#   'participant': [array([], dtype=int64), array([188])],
#   'response': [array([], dtype=int64), array([2467])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2467, 2476, 2499]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([188])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1199])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2467, 2476, 2499]),
#    array([1199])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([188])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1200])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2467, 2476, 2499]),
#    array([1199, 1200])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([188])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1231])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2450, 2467, 2476, 2499]),
#    array([1199, 1200, 1231])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([188])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1219])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1119])],
#   'participant': [array([], dtype=int64), array([194])],
#   'response': [array([], dtype=int64), array([1424])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1119, 1424])],
#   'participant': [array([], dtype=int64), array([194])],
#   'response': [array([], dtype=int64), array([1524])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([1119, 1424, 1524])],
#   'participant': [array([], dtype=int64), array([194])],
#   'response': [array([], dtype=int64), array([1325])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1119, 1325, 1424, 1524]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([194])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1805])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1119, 1325, 1424, 1524]),
#    array([1805])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([194])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1460])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1119, 1325, 1424, 1524]),
#    array([1460, 1805])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([194])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1418])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1119, 1325, 1424, 1524]),
#    array([1418, 1460, 1805])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([194])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1571])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([1886])],
#   'participant': [array([], dtype=int64), array([198])],
#   'response': [array([], dtype=int64), array([1882])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([1882, 1886])],
#   'participant': [array([], dtype=int64), array([198])],
#   'response': [array([], dtype=int64), array([2238])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([1882, 1886, 2238])],
#   'participant': [array([], dtype=int64), array([198])],
#   'response': [array([], dtype=int64), array([2242])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([1882, 1886, 2238, 2242]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([198])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([23])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([1882, 1886, 2238, 2242]),
#    array([23])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([198])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([77])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([1882, 1886, 2238, 2242]),
#    array([23, 77])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([198])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([79])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([1882, 1886, 2238, 2242]),
#    array([23, 77, 79])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([198])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([28])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([254])],
#   'participant': [array([], dtype=int64), array([200])],
#   'response': [array([], dtype=int64), array([1250])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([ 254, 1250])],
#   'participant': [array([], dtype=int64), array([200])],
#   'response': [array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([ 254, 1250, 2450])],
#   'participant': [array([], dtype=int64), array([200])],
#   'response': [array([], dtype=int64), array([2499])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 254, 1250, 2450, 2499]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([200])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1250])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 254, 1250, 2450, 2499]),
#    array([1250])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([200])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1173])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 254, 1250, 2450, 2499]),
#    array([1173, 1250])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([200])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1237])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([ 254, 1250, 2450, 2499]),
#    array([1173, 1237, 1250])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([200])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1249])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2453])],
#   'participant': [array([], dtype=int64), array([206])],
#   'response': [array([], dtype=int64), array([2484])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2453, 2484])],
#   'participant': [array([], dtype=int64), array([206])],
#   'response': [array([], dtype=int64), array([2459])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([2453, 2459, 2484])],
#   'participant': [array([], dtype=int64), array([206])],
#   'response': [array([], dtype=int64), array([2475])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2453, 2459, 2475, 2484]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([206])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([13])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2453, 2459, 2475, 2484]),
#    array([13])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([206])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([22])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2453, 2459, 2475, 2484]),
#    array([13, 22])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([206])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([0])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([2453, 2459, 2475, 2484]),
#    array([ 0, 13, 22])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([206])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([35])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([850])],
#   'participant': [array([], dtype=int64), array([211])],
#   'response': [array([], dtype=int64), array([2150])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([ 850, 2150])],
#   'participant': [array([], dtype=int64), array([211])],
#   'response': [array([], dtype=int64), array([0])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
# ...
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([ 500, 2450, 2461, 2489]),
#    array([1500])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([408])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2063])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([ 500, 2450, 2461, 2489]),
#    array([1500, 2063])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([408])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2119])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([ 500, 2450, 2461, 2489]),
#    array([1500, 2063, 2119])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([408])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2049])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1450])],
#   'participant': [array([], dtype=int64), array([410])],
#   'response': [array([], dtype=int64), array([800])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([ 800, 1450])],
#   'participant': [array([], dtype=int64), array([410])],
#   'response': [array([], dtype=int64), array([2150])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([ 800, 1450, 2150])],
#   'participant': [array([], dtype=int64), array([410])],
#   'response': [array([], dtype=int64), array([1600])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([ 800, 1450, 1600, 2150]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([410])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2484])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([ 800, 1450, 1600, 2150]),
#    array([2484])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([410])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2476])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([ 800, 1450, 1600, 2150]),
#    array([2476, 2484])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([410])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2466])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([ 800, 1450, 1600, 2150]),
#    array([2466, 2476, 2484])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([410])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2457])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([2095, 2499])],
#   'participant': [array([], dtype=int64), array([420])],
#   'response': [array([], dtype=int64), array([2398])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([2095, 2398, 2499])],
#   'participant': [array([], dtype=int64), array([420])],
#   'response': [array([], dtype=int64), array([1945])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1945, 2095, 2398, 2499]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([420])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1945, 2095, 2398, 2499]),
#    array([2450])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([420])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2452])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1945, 2095, 2398, 2499]),
#    array([2450, 2452])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([420])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2053])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([1945, 2095, 2398, 2499]),
#    array([2053, 2450, 2452])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([420])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2057])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([2271, 2499])],
#   'participant': [array([], dtype=int64), array([422])],
#   'response': [array([], dtype=int64), array([2322])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([2271, 2322, 2499])],
#   'participant': [array([], dtype=int64), array([422])],
#   'response': [array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([2271, 2322, 2450, 2499]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([422])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([49])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([2271, 2322, 2450, 2499]),
#    array([49])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([422])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([166])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([2271, 2322, 2450, 2499]),
#    array([ 49, 166])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([422])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([22])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([2271, 2322, 2450, 2499]),
#    array([ 22,  49, 166])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([422])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([150])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([0, 2])],
#   'participant': [array([], dtype=int64), array([425])],
#   'response': [array([], dtype=int64), array([50])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]), array([ 0,  2, 50])],
#   'participant': [array([], dtype=int64), array([425])],
#   'response': [array([], dtype=int64), array([100])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([  0,   2,  50, 100]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([425])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([49])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([  0,   2,  50, 100]),
#    array([49])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([425])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([149])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([  0,   2,  50, 100]),
#    array([ 49, 149])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([425])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([48])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([421, 493, 582, 612]),
#    array([  0,   2,  50, 100]),
#    array([ 48,  49, 149])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([425])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([99])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([2450])],
#   'participant': [array([], dtype=int64), array([426])],
#   'response': [array([], dtype=int64), array([49])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([  49, 2450])],
#   'participant': [array([], dtype=int64), array([426])],
#   'response': [array([], dtype=int64), array([2458])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]), array([  49, 2450, 2458])],
#   'participant': [array([], dtype=int64), array([426])],
#   'response': [array([], dtype=int64), array([36])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  36,   49, 2450, 2458]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([426])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([24])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  36,   49, 2450, 2458]),
#    array([24])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([426])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([2475])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  36,   49, 2450, 2458]),
#    array([  24, 2475])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([426])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([588])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 403,  818, 1479, 1890]),
#    array([  36,   49, 2450, 2458]),
#    array([  24,  588, 2475])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([426])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1813])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2499])],
#   'participant': [array([], dtype=int64), array([428])],
#   'response': [array([], dtype=int64), array([2450])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([2073, 2450, 2499])],
#   'participant': [array([], dtype=int64), array([428])],
#   'response': [array([], dtype=int64), array([2340])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2073, 2340, 2450, 2499]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([428])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1199])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2073, 2340, 2450, 2499]),
#    array([1199])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([428])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1200])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2073, 2340, 2450, 2499]),
#    array([1199, 1200])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([428])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1327])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([2073, 2340, 2450, 2499]),
#    array([1199, 1200, 1327])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([428])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([1216])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1654])],
#   'participant': [array([], dtype=int64), array([434])],
#   'response': [array([], dtype=int64), array([1761])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1654, 1761])],
#   'participant': [array([], dtype=int64), array([434])],
#   'response': [array([], dtype=int64), array([1662])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]), array([1654, 1662, 1761])],
#   'participant': [array([], dtype=int64), array([434])],
#   'response': [array([], dtype=int64), array([1344])],
#   'wrap_ax': [array([], dtype=int64), array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1344, 1654, 1662, 1761]),
#    array([], dtype=float64)],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([434])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([425])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1344, 1654, 1662, 1761]),
#    array([425])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([434])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([779])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1344, 1654, 1662, 1761]),
#    array([425, 779])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([434])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([878])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]},
#  {'categories': [array([ 392,  583, 1083, 1093]),
#    array([1344, 1654, 1662, 1761]),
#    array([425, 779, 878])],
#   'participant': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([434])],
#   'response': [array([], dtype=int64), array([], dtype=int64), array([928])],
#   'wrap_ax': [array([], dtype=int64),
#    array([], dtype=int64),
#    array([None], dtype=object)]}]
